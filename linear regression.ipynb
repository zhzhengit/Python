# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from matplotlib.pyplot import MultipleLocator
x_train = np.array([[0,3],[1,3],[2,3],[3,2],[4,5],[5,3],[6,2],[7,4],[8,2]])
y_train = np.array([95.364693,87.217205,75.195834,60.105519,49.342380,37.400286,30.56456,25.56454,5.654654])
theta_last = [10,10,10]
fig = plt.figure()
ax1 = plt.axes(projection='3d')
fig=plt.figure()

def h(x):
    return theta_last[0]*x[0]+theta_last[1]*x[1]+theta_last[2]
def grad_sum(interation,rate,error):
    for i in range(interation):
        theta_guess = [0,0,0]
        for x,y in zip(x_train,y_train):
            theta_guess[0] = theta_guess[0] + rate*(y-h(x))*x[0]
            theta_guess[1] = theta_guess[1] + rate*(y-h(x))*x[1]
            theta_guess[2] = theta_guess[2] + rate*(y-h(x))*1
           
            if (abs(theta_last[0]-theta_guess[0])<error or abs(theta_last[1]-theta_guess[1])<error or abs(theta_last[2]-theta_guess[2])<error ):
                print('当迭代次数i=',i,'时，达到所需精度，此时theta为：',theta_last[0],theta_last[1],theta_last[2])
                break
            else:
                theta_last[0] = theta_last[0] + theta_guess[0]
                theta_last[1] = theta_last[1] + theta_guess[1]
                theta_last[2] = theta_last[2] + theta_guess[2]
               
        else:
            print('theta0的第',i,'次迭代，theta0=',theta_last[0])
            print('theta1的第',i,'次迭代，theta1=',theta_last[1])
            print('theta2的第',i,'次迭代，theta2=',theta_last[2])
            continue
        break          
if __name__=='__main__':
    grad_sum(interation = 1000,rate=0.01,error= 1e-3)
    result = [h(i) for i in  x_train]
    print(result)
x1=np.arange(0,9,1)
x2=np.arange(0,9,1)
y = theta_last[0]*x1+theta_last[1]*x2+theta_last[2]
ax1.scatter(x1, x2, y_train, c='r')
ax1.plot3D(x1,x2,y,'blue')
plt.tight_layout()
plt.show()
# Out:
# theta0的第 0 次迭代，theta0= -9.703938640698686
# theta1的第 0 次迭代，theta1= 3.4086832660026753
# theta2的第 0 次迭代，theta2= 10.826692785784395
# theta0的第 1 次迭代，theta0= -17.740301670587947
# theta1的第 1 次迭代，theta1= 30.35395102446285
# theta2的第 1 次迭代，theta2= 22.973310565806724
# theta0的第 2 次迭代，theta0= -4.180777473511823
# theta1的第 2 次迭代，theta1= 23.326941003995284
# theta2的第 2 次迭代，theta2= 23.55734124393534
# theta0的第 3 次迭代，theta0= -4.57597935755348
# theta1的第 3 次迭代，theta1= 9.562402716426034
# theta2的第 3 次迭代，theta2= 21.699509590153212
# theta0的第 4 次迭代，theta0= -12.084837181321479
# theta1的第 4 次迭代，theta1= 17.000215263563252
# theta2的第 4 次迭代，theta2= 26.91568007441544
# theta0的第 5 次迭代，theta0= -9.389488597703158
# theta1的第 5 次迭代，theta1= 20.85349242982862
# theta2的第 5 次迭代，theta2= 30.85652477737123
# theta0的第 6 次迭代，theta0= -6.2912883875264205
# theta1的第 6 次迭代，theta1= 14.248189567828256
# theta2的第 6 次迭代，theta2= 31.15527164077014
# theta0的第 7 次迭代，theta0= -8.981004842293517
# theta1的第 7 次迭代，theta1= 13.299451811225945
# theta2的第 7 次迭代，theta2= 33.26437307780515
# theta0的第 8 次迭代，theta0= -9.880413378036838
# theta1的第 8 次迭代，theta1= 16.219493745222263
# theta2的第 8 次迭代，theta2= 36.6077748970329
# theta0的第 9 次迭代，theta0= -8.19104315571258
# theta1的第 9 次迭代，theta1= 14.700764154958241
# theta2的第 9 次迭代，theta2= 38.37057638237696
# theta0的第 10 次迭代，theta0= -8.388080789902315
# theta1的第 10 次迭代，theta1= 12.616114670738504
# theta2的第 10 次迭代，theta2= 39.854286663110265
# theta0的第 11 次迭代，theta0= -9.3604685483887
# theta1的第 11 次迭代，theta1= 13.221724674429668
# theta2的第 11 次迭代，theta2= 42.17145502692987
# theta0的第 12 次迭代，theta0= -9.015055922799228
# theta1的第 12 次迭代，theta1= 13.240705089793778
# theta2的第 12 次迭代，theta2= 44.21981297705911
# theta0的第 13 次迭代，theta0= -8.69403855139022
# theta1的第 13 次迭代，theta1= 12.005674531396515
# theta2的第 13 次迭代，theta2= 45.770435767804585
# theta0的第 14 次迭代，theta0= -9.091091625507227
# theta1的第 14 次迭代，theta1= 11.562350287536736
# theta2的第 14 次迭代，theta2= 47.51793379456708
# theta0的第 15 次迭代，theta0= -9.222043694256133
# theta1的第 15 次迭代，theta1= 11.569170142748346
# theta2的第 15 次迭代，theta2= 49.352386458499076
# theta0的第 16 次迭代，theta0= -9.04440066237291
# theta1的第 16 次迭代，theta1= 11.010435332799208
# theta2的第 16 次迭代，theta2= 50.931419705388066
# theta0的第 17 次迭代，theta0= -9.118196067019287
# theta1的第 17 次迭代，theta1= 10.426905899995877
# theta2的第 17 次迭代，theta2= 52.43886326063489
# theta0的第 18 次迭代，theta0= -9.272669682197758
# theta1的第 18 次迭代，theta1= 10.192504094706381
# theta2的第 18 次迭代，theta2= 54.00450303646823
# theta0的第 19 次迭代，theta0= -9.256979927748912
# theta1的第 19 次迭代，theta1= 9.876921619449494
# theta2的第 19 次迭代，theta2= 55.48526255486256
# theta0的第 20 次迭代，theta0= -9.252894816048943
# theta1的第 20 次迭代，theta1= 9.421479418288829
# theta2的第 20 次迭代，theta2= 56.86258869496603
# theta0的第 21 次迭代，theta0= -9.336364296465957
# theta1的第 21 次迭代，theta1= 9.08401846275633
# theta2的第 21 次迭代，theta2= 58.22572115582217
# theta0的第 22 次迭代，theta0= -9.380429479004434
# theta1的第 22 次迭代，theta1= 8.806676099027358
# theta2的第 22 次迭代，theta2= 59.55737788986935
# theta0的第 23 次迭代，theta0= -9.387181817294236
# theta1的第 23 次迭代，theta1= 8.465879898136714
# theta2的第 23 次迭代，theta2= 60.817423572153444
# theta0的第 24 次迭代，theta0= -9.426310313466892
# theta1的第 24 次迭代，theta1= 8.135777043478106
# theta2的第 24 次迭代，theta2= 62.032546352243486
# theta0的第 25 次迭代，theta0= -9.472549471634661
# theta1的第 25 次迭代，theta1= 7.858306363278584
# theta2的第 25 次迭代，theta2= 63.21878476157508
# theta0的第 26 次迭代，theta0= -9.496148164005497
# theta1的第 26 次迭代，theta1= 7.577090284761756
# theta2的第 26 次迭代，theta2= 64.35875007156753
# theta0的第 27 次迭代，theta0= -9.521508379322684
# theta1的第 27 次迭代，theta1= 7.287748131382778
# theta2的第 27 次迭代，theta2= 65.45245230693432
# theta0的第 28 次迭代，theta0= -9.556715570839476
# theta1的第 28 次迭代，theta1= 7.022335700333618
# theta2的第 28 次迭代，theta2= 66.51227774584754
# theta0的第 29 次迭代，theta0= -9.585519134412836
# theta1的第 29 次迭代，theta1= 6.771481776642618
# theta2的第 29 次迭代，theta2= 67.53658151643579
# theta0的第 30 次迭代，theta0= -9.60915215970616
# theta1的第 30 次迭代，theta1= 6.5200360313362555
# theta2的第 30 次迭代，theta2= 68.52164013885165
# theta0的第 31 次迭代，theta0= -9.63625667449482
# theta1的第 31 次迭代，theta1= 6.277825015962346
# theta2的第 31 次迭代，theta2= 69.47213371239229
# theta0的第 32 次迭代，theta0= -9.663215515833903
# theta1的第 32 次迭代，theta1= 6.049228123308583
# theta2的第 32 次迭代，theta2= 70.390889385007
# theta0的第 33 次迭代，theta0= -9.686560725396413
# theta1的第 33 次迭代，theta1= 5.826701207022083
# theta2的第 33 次迭代，theta2= 71.27663836105042
# theta0的第 34 次迭代，theta0= -9.709561140106148
# theta1的第 34 次迭代，theta1= 5.609877042277276
# theta2的第 34 次迭代，theta2= 72.13047896456274
# theta0的第 35 次迭代，theta0= -9.733062201407474
# theta1的第 35 次迭代，theta1= 5.402521650005015
# theta2的第 35 次迭代，theta2= 72.95487840887891
# theta0的第 36 次迭代，theta0= -9.755016753579905
# theta1的第 36 次迭代，theta1= 5.203009710577425
# theta2的第 36 次迭代，theta2= 73.75044194154371
# theta0的第 37 次迭代，theta0= -9.775722167932066
# theta1的第 37 次迭代，theta1= 5.009316231713748
# theta2的第 37 次迭代，theta2= 74.51759000861117
# theta0的第 38 次迭代，theta0= -9.796262325121289
# theta1的第 38 次迭代，theta1= 4.822559138503647
# theta2的第 38 次迭代，theta2= 75.25776830747822
# theta0的第 39 次迭代，theta0= -9.81614748825784
# theta1的第 39 次迭代，theta1= 4.643003815258739
# theta2的第 39 次迭代，theta2= 75.97210116444755
# theta0的第 40 次迭代，theta0= -9.834996699411523
# theta1的第 40 次迭代，theta1= 4.469487099498245
# theta2的第 40 次迭代，theta2= 76.66119109098695
# theta0的第 41 次迭代，theta0= -9.85326118490284
# theta1的第 41 次迭代，theta1= 4.301829888695184
# theta2的第 41 次迭代，theta2= 77.32593661398423
# theta0的第 42 次迭代，theta0= -9.87104135356557
# theta1的第 42 次迭代，theta1= 4.140318147912119
# theta2的第 42 次迭代，theta2= 77.96736163338458
# theta0的第 43 次迭代，theta0= -9.888096797544781
# theta1的第 43 次迭代，theta1= 3.9845460972222186
# theta2的第 43 次迭代，theta2= 78.58622377623666
# theta0的第 44 次迭代，theta0= -9.904498186809153
# theta1的第 44 次迭代，theta1= 3.8341047517244466
# theta2的第 44 次迭代，theta2= 79.18324694576869
# theta0的第 45 次迭代，theta0= -9.920395487996412
# theta1的第 45 次迭代，theta1= 3.688983203293641
# theta2的第 45 次迭代，theta2= 79.75925953894573
# theta0的第 46 次迭代，theta0= -9.935737368330098
# theta1的第 46 次迭代，theta1= 3.5490474277081008
# theta2的第 46 次迭代，theta2= 80.31501957457097
# theta0的第 47 次迭代，theta0= -9.950497044268776
# theta1的第 47 次迭代，theta1= 3.413998456595996
# theta2的第 47 次迭代，theta2= 80.85120069212107
# theta0的第 48 次迭代，theta0= -9.964749363334933
# theta1的第 48 次迭代，theta1= 3.2836751542041993
# theta2的第 48 次迭代，theta2= 81.36849567307452
# theta0的第 49 次迭代，theta0= -9.97851898782523
# theta1的第 49 次迭代，theta1= 3.1579718469744282
# theta2的第 49 次迭代，theta2= 81.86758999043155
# theta0的第 50 次迭代，theta0= -9.991790443261076
# theta1的第 50 次迭代，theta1= 3.0366987775366865
# theta2的第 50 次迭代，theta2= 82.34911531516762
# theta0的第 51 次迭代，theta0= -10.004588771333562
# theta1的第 51 次迭代，theta1= 2.919675768735337
# theta2的第 51 次迭代，theta2= 82.81368191788187
# theta0的第 52 次迭代，theta0= -10.01694600892819
# theta1的第 52 次迭代，theta1= 2.806776617927241
# theta2的第 52 次迭代，theta2= 83.26189472896863
# theta0的第 53 次迭代，theta0= -10.028868189091984
# theta1的第 53 次迭代，theta1= 2.697861424573998
# theta2的第 53 次迭代，theta2= 83.69433131380913
# theta0的第 54 次迭代，theta0= -10.040365404585962
# theta1的第 54 次迭代，theta1= 2.59277512591961
# theta2的第 54 次迭代，theta2= 84.11154206804329
# theta0的第 55 次迭代，theta0= -10.051459689587137
# theta1的第 55 次迭代，theta1= 2.4913851402084304
# theta2的第 55 次迭代，theta2= 84.51406374523646
# theta0的第 56 次迭代，theta0= -10.062165667430417
# theta1的第 56 次迭代，theta1= 2.3935687714736136
# theta2的第 56 次迭代，theta2= 84.9024159987339
# theta0的第 57 次迭代，theta0= -10.072492938305912
# theta1的第 57 次迭代，theta1= 2.2991964027161558
# theta2的第 57 次迭代，theta2= 85.2770963872109
# theta0的第 58 次迭代，theta0= -10.082456004878471
# theta1的第 58 次迭代，theta1= 2.2081439915561765
# theta2的第 58 次迭代，theta2= 85.63858527689287
# theta0的第 59 次迭代，theta0= -10.092069537425512
# theta1的第 59 次迭代，theta1= 2.12029773800572
# theta2的第 59 次迭代，theta2= 85.98734811518975
# theta0的第 60 次迭代，theta0= -10.101344551451382
# theta1的第 60 次迭代，theta1= 2.0355452485616894
# theta2的第 60 次迭代，theta2= 86.32383309211635
# theta0的第 61 次迭代，theta0= -10.110292388408002
# theta1的第 61 次迭代，theta1= 1.9537757344159599
# theta2的第 61 次迭代，theta2= 86.64847181779643
# theta0的第 62 次迭代，theta0= -10.118925481125782
# theta1的第 62 次迭代，theta1= 1.874884563766774
# theta2的第 62 次迭代，theta2= 86.96168146824166
# theta0的第 63 次迭代，theta0= -10.127254911901707
# theta1的第 63 次迭代，theta1= 1.7987713079516872
# theta2的第 63 次迭代，theta2= 87.26386471250032
# theta0的第 64 次迭代，theta0= -10.135290864026633
# theta1的第 64 次迭代，theta1= 1.7253376434990255
# theta2的第 64 次迭代，theta2= 87.55540955976959
# theta0的第 65 次迭代，theta0= -10.143043844581484
# theta1的第 65 次迭代，theta1= 1.6544889171722017
# theta2的第 65 次迭代，theta2= 87.83669042770111
# theta0的第 66 次迭代，theta0= -10.150524035767194
# theta1的第 66 次迭代，theta1= 1.5861345279123036
# theta2的第 66 次迭代，theta2= 88.10806879680034
# theta0的第 67 次迭代，theta0= -10.157740867741307
# theta1的第 67 次迭代，theta1= 1.5201866987494232
# theta2的第 67 次迭代，theta2= 88.36989329893044
# theta0的第 68 次迭代，theta0= -10.164703550356444
# theta1的第 68 次迭代，theta1= 1.4565604710257085
# theta2的第 68 次迭代，theta2= 88.62250019959072
# theta0的第 69 次迭代，theta0= -10.17142114847858
# theta1的第 69 次迭代，theta1= 1.3951741739296477
# theta2的第 69 次迭代，theta2= 88.86621402615032
# theta0的第 70 次迭代，theta0= -10.177902283753943
# theta1的第 70 次迭代，theta1= 1.3359490594382457
# theta2的第 70 次迭代，theta2= 89.10134789755192
# theta0的第 71 次迭代，theta0= -10.184155218086746
# theta1的第 71 次迭代，theta1= 1.2788089709101054
# theta2的第 71 次迭代，theta2= 89.32820384810623
# theta0的第 72 次迭代，theta0= -10.190188010772339
# theta1的第 72 次迭代，theta1= 1.2236804692810872
# theta2的第 72 次迭代，theta2= 89.54707329102443
# theta0的第 73 次迭代，theta0= -10.196008437881794
# theta1的第 73 次迭代，theta1= 1.170492788495368
# theta2的第 73 次迭代，theta2= 89.75823741001061
# theta0的第 74 次迭代，theta0= -10.201623952667038
# theta1的第 74 次迭代，theta1= 1.1191776032216476
# theta2的第 74 次迭代，theta2= 89.9619674726555
# theta0的第 75 次迭代，theta0= -10.207041762738912
# theta1的第 75 次迭代，theta1= 1.069668962586195
# theta2的第 75 次迭代，theta2= 90.158525185968
# theta0的第 76 次迭代，theta0= -10.212268843325235
# theta1的第 76 次迭代，theta1= 1.021903276298568
# theta2的第 76 次迭代，theta2= 90.34816305661316
# theta0的第 77 次迭代，theta0= -10.217311907395079
# theta1的第 77 次迭代，theta1= 0.9758191964550764
# theta2的第 77 次迭代，theta2= 90.53112470303579
# theta0的第 78 次迭代，theta0= -10.222177425548773
# theta1的第 78 次迭代，theta1= 0.9313575121570561
# theta2的第 78 次迭代，theta2= 90.70764515935511
# theta0的第 79 次迭代，theta0= -10.226871651932127
# theta1的第 79 次迭代，theta1= 0.88846110289368
# theta2的第 79 次迭代，theta2= 90.87795118723018
# theta0的第 80 次迭代，theta0= -10.231400619919548
# theta1的第 80 次迭代，theta1= 0.8470748696608807
# theta2的第 80 次迭代，theta2= 91.04226156873635
# theta0的第 81 次迭代，theta0= -10.23577014440188
# theta1的第 81 次迭代，theta1= 0.8071456463068032
# theta2的第 81 次迭代，theta2= 91.20078738137018
# theta0的第 82 次迭代，theta0= -10.239985837994407
# theta1的第 82 次迭代，theta1= 0.7686221349461143
# theta2的第 82 次迭代，theta2= 91.35373227043375
# theta0的第 83 次迭代，theta0= -10.244053118239778
# theta1的第 83 次迭代，theta1= 0.7314548486728834
# theta2的第 83 次迭代，theta2= 91.50129271356724
# theta0的第 84 次迭代，theta0= -10.247977209729669
# theta1的第 84 次迭代，theta1= 0.6955960429422013
# theta2的第 84 次迭代，theta2= 91.64365827145369
# theta0的第 85 次迭代，theta0= -10.251763152499823
# theta1的第 85 次迭代，theta1= 0.6609996512177323
# theta2的第 85 次迭代，theta2= 91.78101183030263
# theta0的第 86 次迭代，theta0= -10.255415810600134
# theta1的第 86 次迭代，theta1= 0.6276212296364196
# theta2的第 86 次迭代，theta2= 91.91352983808797
# theta0的第 87 次迭代，theta0= -10.258939876683211
# theta1的第 87 次迭代，theta1= 0.5954179002527744
# theta2的第 87 次迭代，theta2= 92.04138253133874
# theta0的第 88 次迭代，theta0= -10.26233987744811
# theta1的第 88 次迭代，theta1= 0.5643482937104954
# theta2的第 88 次迭代，theta2= 92.1647341530689
# theta0的第 89 次迭代，theta0= -10.265620180577898
# theta1的第 89 次迭代，theta1= 0.5343724966907282
# theta2的第 89 次迭代，theta2= 92.28374316396558
# theta0的第 90 次迭代，theta0= -10.268785000284671
# theta1的第 90 次迭代，theta1= 0.5054520016769859
# theta2的第 90 次迭代，theta2= 92.39856244630477
# theta0的第 91 次迭代，theta0= -10.271838402124317
# theta1的第 91 次迭代，theta1= 0.47754965679854017
# theta2的第 91 次迭代，theta2= 92.5093395001164
# theta0的第 92 次迭代，theta0= -10.274784308463625
# theta1的第 92 次迭代，theta1= 0.45062961776791355
# theta2的第 92 次迭代，theta2= 92.61621663255187
# theta0的第 93 次迭代，theta0= -10.277626503765994
# theta1的第 93 次迭代，theta1= 0.4246573023325996
# theta2的第 93 次迭代，theta2= 92.71933114086386
# theta0的第 94 次迭代，theta0= -10.280368639231982
# theta1的第 94 次迭代，theta1= 0.39959934586302887
# theta2的第 94 次迭代，theta2= 92.81881548878756
# theta0的第 95 次迭代，theta0= -10.283014237429663
# theta1的第 95 次迭代，theta1= 0.3754235582108568
# theta2的第 95 次迭代，theta2= 92.91479747661202
# theta0的第 96 次迭代，theta0= -10.285566696963162
# theta1的第 96 次迭代，theta1= 0.35209888244664456
# theta2的第 96 次迭代，theta2= 93.00740040538594
# theta0的第 97 次迭代，theta0= -10.288029296822094
# theta1的第 97 次迭代，theta1= 0.32959535508755244
# theta2的第 97 次迭代，theta2= 93.09674323535577
# theta0的第 98 次迭代，theta0= -10.290405200520155
# theta1的第 98 次迭代，theta1= 0.3078840675123261
# theta2的第 98 次迭代，theta2= 93.18294073875404
# theta0的第 99 次迭代，theta0= -10.292697460193802
# theta1的第 99 次迭代，theta1= 0.2869371287880754
# theta2的第 99 次迭代，theta2= 93.26610364722622
# theta0的第 100 次迭代，theta0= -10.29490902055186
# theta1的第 100 次迭代，theta1= 0.26672762990499976
# theta2的第 100 次迭代，theta2= 93.34633879410144
# theta0的第 101 次迭代，theta0= -10.297042722629122
# theta1的第 101 次迭代，theta1= 0.24722960920623657
# theta2的第 101 次迭代，theta2= 93.4237492516328
# theta0的第 102 次迭代，theta0= -10.299101307430298
# theta1的第 102 次迭代，theta1= 0.22841801900201805
# theta2的第 102 次迭代，theta2= 93.498434463395
# theta0的第 103 次迭代，theta0= -10.30108741946933
# theta1的第 103 次迭代，theta1= 0.21026869340595644
# theta2的第 103 次迭代，theta2= 93.57049037203666
# theta0的第 104 次迭代，theta0= -10.303003610163508
# theta1的第 104 次迭代，theta1= 0.19275831730558954
# theta2的第 104 次迭代，theta2= 93.64000954253594
# theta0的第 105 次迭代，theta0= -10.304852341102073
# theta1的第 105 次迭代，theta1= 0.17586439639870818
# theta2的第 105 次迭代，theta2= 93.70708128110768
# theta0的第 106 次迭代，theta0= -10.306635987213351
# theta1的第 106 次迭代，theta1= 0.15956522829273734
# theta2的第 106 次迭代，theta2= 93.77179174992743
# theta0的第 107 次迭代，theta0= -10.30835683981888
# theta1的第 107 次迭代，theta1= 0.1438398746335028
# theta2的第 107 次迭代，theta2= 93.8342240778205
# theta0的第 108 次迭代，theta0= -10.310017109573096
# theta1的第 108 次迭代，theta1= 0.12866813420646797
# theta2的第 108 次迭代，theta2= 93.89445846705108
# theta0的第 109 次迭代，theta0= -10.311618929302721
# theta1的第 109 次迭代，theta1= 0.1140305169814583
# theta2的第 109 次迭代，theta2= 93.95257229635098
# theta0的第 110 次迭代，theta0= -10.313164356748928
# theta1的第 110 次迭代，theta1= 0.09990821907710726
# theta2的第 110 次迭代，theta2= 94.00864022032296
# theta0的第 111 次迭代，theta0= -10.314655377210254
# theta1的第 111 次迭代，theta1= 0.08628309860662192
# theta2的第 111 次迭代，theta2= 94.0627342653448
# theta0的第 112 次迭代，theta0= -10.316093906091869
# theta1的第 112 次迭代，theta1= 0.07313765237053163
# theta2的第 112 次迭代，theta2= 94.11492392209561
# theta0的第 113 次迭代，theta0= -10.317481791366848
# theta1的第 113 次迭代，theta1= 0.06045499337127691
# theta2的第 113 次迭代，theta2= 94.16527623482547
# theta0的第 114 次迭代，theta0= -10.318820815950472
# theta1的第 114 次迭代，theta1= 0.04821882912072159
# theta2的第 114 次迭代，theta2= 94.21385588748251
# theta0的第 115 次迭代，theta0= -10.320112699990121
# theta1的第 115 次迭代，theta1= 0.036413440710247214
# theta2的第 115 次迭代，theta2= 94.26072528680766
# theta0的第 116 次迭代，theta0= -10.321359103075007
# theta1的第 116 次迭代，theta1= 0.025023662617271902
# theta2的第 116 次迭代，theta2= 94.30594464250393
# theta0的第 117 次迭代，theta0= -10.32256162636838
# theta1的第 117 次迭代，theta1= 0.014034863223498617
# theta2的第 117 次迭代，theta2= 94.34957204458348
# theta0的第 118 次迭代，theta0= -10.323721814664376
# theta1的第 118 次迭代，theta1= 0.003432926018910376
# theta2的第 118 次迭代，theta2= 94.39166353799163
# theta0的第 119 次迭代，theta0= -10.324841158372365
# theta1的第 119 次迭代，theta1= -0.006795768532864593
# theta2的第 119 次迭代，theta2= 94.43227319460377
# theta0的第 120 次迭代，theta0= -10.325921095431644
# theta1的第 120 次迭代，theta1= -0.016664360490629526
# theta2的第 120 次迭代，theta2= 94.47145318268744
# theta0的第 121 次迭代，theta0= -10.326963013158684
# theta1的第 121 次迭代，theta1= -0.02618552731558821
# theta2的第 121 次迭代，theta2= 94.50925383391916
# theta0的第 122 次迭代，theta0= -10.327968250029313
# theta1的第 122 次迭代，theta1= -0.0353715001571521
# theta2的第 122 次迭代，theta2= 94.54572370804192
# theta0的第 123 次迭代，theta0= -10.328938097398098
# theta1的第 123 次迭代，theta1= -0.044234079565449835
# theta2的第 123 次迭代，theta2= 94.5809096552463
# theta0的第 124 次迭代，theta0= -10.329873801157298
# theta1的第 124 次迭代，theta1= -0.05278465065064997
# theta2的第 124 次迭代，theta2= 94.61485687635547
# theta0的第 125 次迭代，theta0= -10.330776563337373
# theta1的第 125 次迭代，theta1= -0.06103419770855126
# theta2的第 125 次迭代，theta2= 94.64760898089146
# theta0的第 126 次迭代，theta0= -10.331647543651128
# theta1的第 126 次迭代，theta1= -0.06899331833129424
# theta2的第 126 次迭代，theta2= 94.67920804309705
# theta0的第 127 次迭代，theta0= -10.332487860983539
# theta1的第 127 次迭代，theta1= -0.0766722370213472
# theta2的第 127 次迭代，theta2= 94.70969465598554
# theta0的第 128 次迭代，theta0= -10.333298594829062
# theta1的第 128 次迭代，theta1= -0.08408081832614445
# theta2的第 128 次迭代，theta2= 94.73910798348773
# theta0的第 129 次迭代，theta0= -10.334080786678387
# theta1的第 129 次迭代，theta1= -0.09122857951043134
# theta2的第 129 次迭代，theta2= 94.76748581076271
# theta0的第 130 次迭代，theta0= -10.334835441356432
# theta1的第 130 次迭代，theta1= -0.09812470278229357
# theta2的第 130 次迭代，theta2= 94.79486459273795
# theta0的第 131 次迭代，theta0= -10.33556352831308
# theta1的第 131 次迭代，theta1= -0.10477804708891619
# theta2的第 131 次迭代，theta2= 94.82127950094025
# theta0的第 132 次迭代，theta0= -10.336265982868582
# theta1的第 132 次迭代，theta1= -0.11119715949708386
# theta2的第 132 次迭代，theta2= 94.84676446867785
# theta0的第 133 次迭代，theta0= -10.336943707415168
# theta1的第 133 次迭代，theta1= -0.11739028617289432
# theta2的第 133 次迭代，theta2= 94.87135223463237
# theta0的第 134 次迭代，theta0= -10.337597572576179
# theta1的第 134 次迭代，theta1= -0.12336538297501184
# theta2的第 134 次迭代，theta2= 94.89507438491556
# theta0的第 135 次迭代，theta0= -10.338228418324553
# theta1的第 135 次迭代，theta1= -0.129130125675046
# theta2的第 135 次迭代，theta2= 94.91796139364583
# theta0的第 136 次迭代，theta0= -10.338837055061859
# theta1的第 136 次迭代，theta1= -0.13469191981800582
# theta2的第 136 次迭代，theta2= 94.94004266209598
# theta0的第 137 次迭代，theta0= -10.339424264659396
# theta1的第 137 次迭代，theta1= -0.14005791023566083
# theta2的第 137 次迭代，theta2= 94.96134655646308
# theta0的第 138 次迭代，theta0= -10.339990801462546
# theta1的第 138 次迭代，theta1= -0.14523499022498548
# theta2的第 138 次迭代，theta2= 94.9819004443083
# theta0的第 139 次迭代，theta0= -10.340537393259869
# theta1的第 139 次迭代，theta1= -0.1502298104035388
# theta2的第 139 次迭代，theta2= 95.00173072971404
# theta0的第 140 次迭代，theta0= -10.341064742218027
# theta1的第 140 次迭代，theta1= -0.15504878725292617
# theta2的第 140 次迭代，theta2= 95.0208628872034
# theta0的第 141 次迭代，theta0= -10.34157352578382
# theta1的第 141 次迭代，theta1= -0.15969811136166845
# theta2的第 141 次迭代，theta2= 95.0393214944654
# theta0的第 142 次迭代，theta0= -10.342064397554426
# theta1的第 142 次迭代，theta1= -0.1641837553777531
# theta2的第 142 次迭代，theta2= 95.05713026392814
# theta0的第 143 次迭代，theta0= -10.342537988117051
# theta1的第 143 次迭代，theta1= -0.1685114816812929
# theta2的第 143 次迭代，theta2= 95.07431207322044
# theta0的第 144 次迭代，theta0= -10.34299490585899
# theta1的第 144 次迭代，theta1= -0.1726868497869954
# theta2的第 144 次迭代，theta2= 95.09088899456101
# theta0的第 145 次迭代，theta0= -10.34343573774918
# theta1的第 145 次迭代，theta1= -0.17671522348610985
# theta2的第 145 次迭代，theta2= 95.10688232311314
# theta0的第 146 次迭代，theta0= -10.34386105009225
# theta1的第 146 次迭代，theta1= -0.1806017777368617
# theta2的第 146 次迭代，theta2= 95.12231260434098
# theta0的第 147 次迭代，theta0= -10.344271389255965
# theta1的第 147 次迭代，theta1= -0.18435150531238984
# theta2的第 147 次迭代，theta2= 95.13719966040276
# theta0的第 148 次迭代，theta0= -10.344667282373162
# theta1的第 148 次迭代，theta1= -0.18796922321455023
# theta2的第 148 次迭代，theta2= 95.1515626156149
# theta0的第 149 次迭代，theta0= -10.345049238018898
# theta1的第 149 次迭代，theta1= -0.19145957886198872
# theta2的第 149 次迭代，theta2= 95.16541992101969
# theta0的第 150 次迭代，theta0= -10.345417746863765
# theta1的第 150 次迭代，theta1= -0.19482705606032985
# theta2的第 150 次迭代，theta2= 95.17878937808793
# theta0的第 151 次迭代，theta0= -10.345773282304219
# theta1的第 151 次迭代，theta1= -0.19807598076224195
# theta2的第 151 次迭代，theta2= 95.19168816158715
# theta0的第 152 次迭代，theta0= -10.346116301070749
# theta1的第 152 次迭代，theta1= -0.2012105266246074
# theta2的第 152 次迭代，theta2= 95.2041328416449
# theta0的第 153 次迭代，theta0= -10.34644724381458
# theta1的第 153 次迭代，theta1= -0.20423472037014961
# theta2的第 153 次迭代，theta2= 95.2161394050351
# theta0的第 154 次迭代，theta0= -10.346766535673748
# theta1的第 154 次迭代，theta1= -0.2071524469602726
# theta2的第 154 次迭代，theta2= 95.22772327571509
# theta0的第 155 次迭代，theta0= -10.347074586819236
# theta1的第 155 次迭代，theta1= -0.20996745458578275
# theta2的第 155 次迭代，theta2= 95.23889933463971
# theta0的第 156 次迭代，theta0= -10.347371792981903
# theta1的第 156 次迭代，theta1= -0.21268335948191025
# theta2的第 156 次迭代，theta2= 95.24968193887764
# theta0的第 157 次迭代，theta0= -10.347658535960884
# theta1的第 157 次迭代，theta1= -0.2153036505738306
# theta2的第 157 次迭代，theta2= 95.26008494005512
# theta0的第 158 次迭代，theta0= -10.347935184113974
# theta1的第 158 次迭代，theta1= -0.2178316939586103
# theta2的第 158 次迭代，theta2= 95.27012170214995
# theta0的第 159 次迭代，theta0= -10.348202092830906
# theta1的第 159 次迭代，theta1= -0.22027073722945817
# theta2的第 159 次迭代，theta2= 95.27980511865923
# theta0的第 160 次迭代，theta0= -10.348459604989863
# theta1的第 160 次迭代，theta1= -0.2226239136475624
# theta2的第 160 次迭代，theta2= 95.28914762916273
# theta0的第 161 次迭代，theta0= -10.348708051397958
# theta1的第 161 次迭代，theta1= -0.2248942461672651
# theta2的第 161 次迭代，theta2= 95.29816123530311
# theta0的第 162 次迭代，theta0= -10.348947751216206
# theta1的第 162 次迭代，theta1= -0.2270846513193562
# theta2的第 162 次迭代，theta2= 95.30685751620362
# theta0的第 163 次迭代，theta0= -10.349179012369483
# theta1的第 163 次迭代，theta1= -0.22919794295776008
# theta2的第 163 次迭代，theta2= 95.31524764334279
# theta0的第 164 次迭代，theta0= -10.349402131942146
# theta1的第 164 次迭代，theta1= -0.23123683587432126
# theta2的第 164 次迭代，theta2= 95.32334239490574
# theta0的第 165 次迭代，theta0= -10.349617396559678
# theta1的第 165 次迭代，theta1= -0.23320394928621913
# theta2的第 165 次迭代，theta2= 95.33115216963014
# theta0的第 166 次迭代，theta0= -10.349825082756837
# theta1的第 166 次迭代，theta1= -0.23510181020076026
# theta2的第 166 次迭代，theta2= 95.3386870001647
# theta0的第 167 次迭代，theta0= -10.350025457332942
# theta1的第 167 次迭代，theta1= -0.2369328566616265
# theta2的第 167 次迭代，theta2= 95.3459565659573
# theta0的第 168 次迭代，theta0= -10.350218777694629
# theta1的第 168 次迭代，theta1= -0.2386994408808128
# theta2的第 168 次迭代，theta2= 95.35297020568952
# theta0的第 169 次迭代，theta0= -10.350405292186485
# theta1的第 169 次迭代，theta1= -0.2404038322603583
# theta2的第 169 次迭代，theta2= 95.35973692927342
# theta0的第 170 次迭代，theta0= -10.350585240410076
# theta1的第 170 次迭代，theta1= -0.24204822030771658
# theta2的第 170 次迭代，theta2= 95.36626542942587
# theta0的第 171 次迭代，theta0= -10.350758853531786
# theta1的第 171 次迭代，theta1= -0.24363471744844356
# theta2的第 171 次迭代，theta2= 95.3725640928354
# theta0的第 172 次迭代，theta0= -10.35092635457975
# theta1的第 172 次迭代，theta1= -0.2451653617398131
# theta2的第 172 次迭代，theta2= 95.37864101093606
# theta0的第 173 次迭代，theta0= -10.351087958730353
# theta1的第 173 次迭代，theta1= -0.24664211948906048
# theta2的第 173 次迭代，theta2= 95.38450399030187
# theta0的第 174 次迭代，theta0= -10.35124387358468
# theta1的第 174 次迭代，theta1= -0.24806688777928898
# theta2的第 174 次迭代，theta2= 95.39016056267532
# theta0的第 175 次迭代，theta0= -10.351394299435185
# theta1的第 175 次迭代，theta1= -0.24944149690653594
# theta2的第 175 次迭代，theta2= 95.39561799464286
# theta0的第 176 次迭代，theta0= -10.351539429523003
# theta1的第 176 次迭代，theta1= -0.25076771273099635
# theta2的第 176 次迭代，theta2= 95.40088329696981
# theta0的第 177 次迭代，theta0= -10.351679450286179
# theta1的第 177 次迭代，theta1= -0.2520472389455416
# theta2的第 177 次迭代，theta2= 95.40596323360649
# theta0的第 178 次迭代，theta0= -10.351814541599186
# theta1的第 178 次迭代，theta1= -0.2532817192642888
# theta2的第 178 次迭代，theta2= 95.41086433037741
# theta0的第 179 次迭代，theta0= -10.351944877004005
# theta1的第 179 次迭代，theta1= -0.2544727395341684
# theta2的第 179 次迭代，theta2= 95.41559288336457
# theta0的第 180 次迭代，theta0= -10.352070623933031
# theta1的第 180 次迭代，theta1= -0.25562182977215175
# theta2的第 180 次迭代，theta2= 95.42015496699558
# theta0的第 181 次迭代，theta0= -10.352191943924172
# theta1的第 181 次迭代，theta1= -0.2567304661307812
# theta2的第 181 次迭代，theta2= 95.4245564418469
# theta0的第 182 次迭代，theta0= -10.352308992828398
# theta1的第 182 次迭代，theta1= -0.2578000727944193
# theta2的第 182 次迭代，theta2= 95.42880296217265
# theta0的第 183 次迭代，theta0= -10.352421921009906
# theta1的第 183 次迭代，theta1= -0.25883202380881104
# theta2的第 183 次迭代，theta2= 95.43289998316816
# theta0的第 184 次迭代，theta0= -10.352530873539301
# theta1的第 184 次迭代，theta1= -0.2598276448462725
# theta2的第 184 次迭代，theta2= 95.43685276797784
# theta0的第 185 次迭代，theta0= -10.352635990379957
# theta1的第 185 次迭代，theta1= -0.2607882149086142
# theta2的第 185 次迭代，theta2= 95.44066639445637
# theta0的第 186 次迭代，theta0= -10.35273740656783
# theta1的第 186 次迭代，theta1= -0.2617149679702266
# theta2的第 186 次迭代，theta2= 95.4443457616919
# theta0的第 187 次迭代，theta0= -10.352835252384908
# theta1的第 187 次迭代，theta1= -0.2626090945632391
# theta2的第 187 次迭代，theta2= 95.44789559629947
# theta0的第 188 次迭代，theta0= -10.352929653526576
# theta1的第 188 次迭代，theta1= -0.2634717433069632
# theta2的第 188 次迭代，theta2= 95.45132045849302
# theta0的第 189 次迭代，theta0= -10.35302073126311
# theta1的第 189 次迭代，theta1= -0.26430402238340556
# theta2的第 189 次迭代，theta2= 95.45462474794348
# theta0的第 190 次迭代，theta0= -10.353108602595444
# theta1的第 190 次迭代，theta1= -0.2651070009608579
# theta2的第 190 次迭代，theta2= 95.45781270943084
# theta0的第 191 次迭代，theta0= -10.35319338040548
# theta1的第 191 次迭代，theta1= -0.26588171056739524
# theta2的第 191 次迭代，theta2= 95.46088843829698
# theta0的第 192 次迭代，theta0= -10.353275173601086
# theta1的第 192 次迭代，theta1= -0.2666291464160264
# theta2的第 192 次迭代，theta2= 95.4638558857067
# theta0的第 193 次迭代，theta0= -10.353354087256022
# theta1的第 193 次迭代，theta1= -0.2673502686831413
# theta2的第 193 次迭代，theta2= 95.46671886372354
# theta0的第 194 次迭代，theta0= -10.35343022274493
# theta1的第 194 次迭代，theta1= -0.26804600374198606
# theta2的第 194 次迭代，theta2= 95.46948105020682
# theta0的第 195 次迭代，theta0= -10.353503677873508
# theta1的第 195 次迭代，theta1= -0.26871724535268593
# theta2的第 195 次迭代，theta2= 95.47214599353624
# theta0的第 196 次迭代，theta0= -10.35357454700421
# theta1的第 196 次迭代，theta1= -0.2693648558104654
# theta2的第 196 次迭代，theta2= 95.47471711717043
# theta0的第 197 次迭代，theta0= -10.353642921177455
# theta1的第 197 次迭代，theta1= -0.2699896670532974
# theta2的第 197 次迭代，theta2= 95.47719772404457
# theta0的第 198 次迭代，theta0= -10.353708888228555
# theta1的第 198 次迭代，theta1= -0.2705924817306589
# theta2的第 198 次迭代，theta2= 95.47959100081363
# theta0的第 199 次迭代，theta0= -10.353772532900578
# theta1的第 199 次迭代，theta1= -0.2711740742346636
# theta2的第 199 次迭代，theta2= 95.4819000219459
# theta0的第 200 次迭代，theta0= -10.353833936953196
# theta1的第 200 次迭代，theta1= -0.27173519169483024
# theta2的第 200 次迭代，theta2= 95.48412775367267
# theta0的第 201 次迭代，theta0= -10.353893179267724
# theta1的第 201 次迭代，theta1= -0.2722765549378783
# theta2的第 201 次迭代，theta2= 95.48627705779857
# theta0的第 202 次迭代，theta0= -10.353950335948443
# theta1的第 202 次迭代，theta1= -0.2727988594137445
# theta2的第 202 次迭代，theta2= 95.48835069537806
# theta0的第 203 次迭代，theta0= -10.354005480420383
# theta1的第 203 次迭代，theta1= -0.27330277608892484
# theta2的第 203 次迭代，theta2= 95.49035133026227
# theta0的第 204 次迭代，theta0= -10.35405868352363
# theta1的第 204 次迭代，theta1= -0.2737889523084718
# theta2的第 204 次迭代，theta2= 95.4922815325211
# theta0的第 205 次迭代，theta0= -10.354110013604334
# theta1的第 205 次迭代，theta1= -0.2742580126275535
# theta2的第 205 次迭代，theta2= 95.49414378174477
# theta0的第 206 次迭代，theta0= -10.354159536602511
# theta1的第 206 次迭代，theta1= -0.27471055961379154
# theta2的第 206 次迭代，theta2= 95.49594047022924
# theta0的第 207 次迭代，theta0= -10.354207316136742
# theta1的第 207 次迭代，theta1= -0.2751471746213546
# theta2的第 207 次迭代，theta2= 95.4976739060493
# theta0的第 208 次迭代，theta0= -10.354253413585925
# theta1的第 208 次迭代，theta1= -0.27556841853770797
# theta2的第 208 次迭代，theta2= 95.49934631602366
# theta0的第 209 次迭代，theta0= -10.35429788816809
# theta1的第 209 次迭代，theta1= -0.2759748325042334
# theta2的第 209 次迭代，theta2= 95.50095984857558
# theta0的第 210 次迭代，theta0= -10.35434079701649
# theta1的第 210 次迭代，theta1= -0.27636693861134964
# theta2的第 210 次迭代，theta2= 95.50251657649281
# theta0的第 211 次迭代，theta0= -10.354382195253
# theta1的第 211 次迭代，theta1= -0.2767452405692075
# theta2的第 211 次迭代，theta2= 95.50401849959029
# theta0的第 212 次迭代，theta0= -10.354422136058915
# theta1的第 212 次迭代，theta1= -0.2771102243547773
# theta2的第 212 次迭代，theta2= 95.5054675472792
# theta0的第 213 次迭代，theta0= -10.354460670743286
# theta1的第 213 次迭代，theta1= -0.2774623588361387
# theta2的第 213 次迭代，theta2= 95.50686558104557
# theta0的第 214 次迭代，theta0= -10.354497848808812
# theta1的第 214 次迭代，theta1= -0.27780209637480274
# theta2的第 214 次迭代，theta2= 95.50821439684152
# theta0的第 215 次迭代，theta0= -10.35453371801544
# theta1的第 215 次迭代，theta1= -0.2781298734068401
# theta2的第 215 次迭代，theta2= 95.50951572739247
# theta0的第 216 次迭代，theta0= -10.354568324441733
# theta1的第 216 次迭代，theta1= -0.2784461110035372
# theta2的第 216 次迭代，theta2= 95.51077124442295
# theta0的第 217 次迭代，theta0= -10.354601712544047
# theta1的第 217 次迭代，theta1= -0.27875121541227615
# theta2的第 217 次迭代，theta2= 95.51198256080424
# theta0的第 218 次迭代，theta0= -10.354633925213639
# theta1的第 218 次迭代，theta1= -0.2790455785784731
# theta2的第 218 次迭代，theta2= 95.51315123262627
# theta0的第 219 次迭代，theta0= -10.354665003831776
# theta1的第 219 次迭代，theta1= -0.27932957864905544
# theta2的第 219 次迭代，theta2= 95.51427876119656
# theta0的第 220 次迭代，theta0= -10.35469498832291
# theta1的第 220 次迭代，theta1= -0.2796035804582205
# theta2的第 220 次迭代，theta2= 95.515366594969
# theta0的第 221 次迭代，theta0= -10.354723917205918
# theta1的第 221 次迭代，theta1= -0.27986793599612336
# theta2的第 221 次迭代，theta2= 95.51641613140433
# theta0的第 222 次迭代，theta0= -10.354751827643637
# theta1的第 222 次迭代，theta1= -0.28012298486108533
# theta2的第 222 次迭代，theta2= 95.51742871876557
# theta0的第 223 次迭代，theta0= -10.354778755490567
# theta1的第 223 次迭代，theta1= -0.28036905469577283
# theta2的第 223 次迭代，theta2= 95.51840565784994
# theta0的第 224 次迭代，theta0= -10.35480473533895
# theta1的第 224 次迭代，theta1= -0.2806064616082191
# theta2的第 224 次迭代，theta2= 95.51934820365992
# theta0的第 225 次迭代，theta0= -10.35482980056322
# theta1的第 225 次迭代，theta1= -0.28083551057775075
# theta2的第 225 次迭代，theta2= 95.52025756701542
# theta0的第 226 次迭代，theta0= -10.35485398336282
# theta1的第 226 次迭代，theta1= -0.2810564958468941
# theta2的第 226 次迭代，theta2= 95.52113491610929
# theta0的第 227 次迭代，theta0= -10.354877314803652
# theta1的第 227 次迭代，theta1= -0.28126970129936313
# theta2的第 227 次迭代，theta2= 95.52198137800805
# theta0的第 228 次迭代，theta0= -10.354899824857913
# theta1的第 228 次迭代，theta1= -0.28147540082462563
# theta2的第 228 次迭代，theta2= 95.52279804009962
# theta0的第 229 次迭代，theta0= -10.354921542442627
# theta1的第 229 次迭代，theta1= -0.28167385866991496
# theta2的第 229 次迭代，theta2= 95.52358595149029
# theta0的第 230 次迭代，theta0= -10.35494249545679
# theta1的第 230 次迭代，theta1= -0.2818653297795496
# theta2的第 230 次迭代，theta2= 95.52434612435243
# theta0的第 231 次迭代，theta0= -10.354962710817219
# theta1的第 231 次迭代，theta1= -0.2820500601225262
# theta2的第 231 次迭代，theta2= 95.52507953522476
# theta0的第 232 次迭代，theta0= -10.354982214493113
# theta1的第 232 次迭代，theta1= -0.28222828700844194
# theta2的第 232 次迭代，theta2= 95.52578712626678
# theta0的第 233 次迭代，theta0= -10.355001031539418
# theta1的第 233 次迭代，theta1= -0.28240023939241776
# theta2的第 233 次迭代，theta2= 95.52646980646915
# theta0的第 234 次迭代，theta0= -10.355019186129034
# theta1的第 234 次迭代，theta1= -0.28256613816913345
# theta2的第 234 次迭代，theta2= 95.5271284528214
# theta0的第 235 次迭代，theta0= -10.355036701583833
# theta1的第 235 次迭代，theta1= -0.2827261964566677
# theta2的第 235 次迭代，theta2= 95.52776391143851
# theta0的第 236 次迭代，theta0= -10.355053600404643
# theta1的第 236 次迭代，theta1= -0.28288061987024754
# theta2的第 236 次迭代，theta2= 95.5283769986479
# theta0的第 237 次迭代，theta0= -10.35506990430015
# theta1的第 237 次迭代，theta1= -0.283029606786383
# theta2的第 237 次迭代，theta2= 95.52896850203803
# theta0的第 238 次迭代，theta0= -10.355085634214777
# theta1的第 238 次迭代，theta1= -0.2831733485977161
# theta2的第 238 次迭代，theta2= 95.5295391814702
# theta0的第 239 次迭代，theta0= -10.355100810355612
# theta1的第 239 次迭代，theta1= -0.2833120299588649
# theta2的第 239 次迭代，theta2= 95.53008977005473
# theta0的第 240 次迭代，theta0= -10.355115452218323
# theta1的第 240 次迭代，theta1= -0.28344582902367693
# theta2的第 240 次迭代，theta2= 95.53062097509266
# theta0的第 241 次迭代，theta0= -10.355129578612246
# theta1的第 241 次迭代，theta1= -0.2835749176740848
# theta2的第 241 次迭代，theta2= 95.53113347898442
# theta0的第 242 次迭代，theta0= -10.355143207684542
# theta1的第 242 次迭代，theta1= -0.2836994617408517
# theta2的第 242 次迭代，theta2= 95.53162794010639
# theta0的第 243 次迭代，theta0= -10.355156356943471
# theta1的第 243 次迭代，theta1= -0.28381962121666365
# theta2的第 243 次迭代，theta2= 95.53210499365676
# theta0的第 244 次迭代，theta0= -10.355169043280943
# theta1的第 244 次迭代，theta1= -0.2839355504616645
# theta2的第 244 次迭代，theta2= 95.5325652524715
# theta0的第 245 次迭代，theta0= -10.355181282994163
# theta1的第 245 次迭代，theta1= -0.2840473984017007
# theta2的第 245 次迭代，theta2= 95.53300930781155
# theta0的第 246 次迭代，theta0= -10.355193091806603
# theta1的第 246 次迭代，theta1= -0.2841553087196704
# theta2的第 246 次迭代，theta2= 95.53343773012253
# theta0的第 247 次迭代，theta0= -10.355204484888173
# theta1的第 247 次迭代，theta1= -0.284259420040111
# theta2的第 247 次迭代，theta2= 95.53385106976725
# theta0的第 248 次迭代，theta0= -10.355215476874758
# theta1的第 248 次迭代，theta1= -0.28435986610723557
# theta2的第 248 次迭代，theta2= 95.53424985773313
# theta0的第 249 次迭代，theta0= -10.355226081886947
# theta1的第 249 次迭代，theta1= -0.28445677595678975
# theta2的第 249 次迭代，theta2= 95.53463460631403
# theta0的第 250 次迭代，theta0= -10.355236313548216
# theta1的第 250 次迭代，theta1= -0.2845502740818164
# theta2的第 250 次迭代，theta2= 95.53500580976838
# theta0的第 251 次迭代，theta0= -10.355246185002454
# theta1的第 251 次迭代，theta1= -0.28464048059253355
# theta2的第 251 次迭代，theta2= 95.53536394495421
# theta0的第 252 次迭代，theta0= -10.355255708930795
# theta1的第 252 次迭代，theta1= -0.2847275113706676
# theta2的第 252 次迭代，theta2= 95.53570947194173
# theta0的第 253 次迭代，theta0= -10.355264897567931
# theta1的第 253 次迭代，theta1= -0.2848114782183235
# theta2的第 253 次迭代，theta2= 95.53604283460429
# theta0的第 254 次迭代，theta0= -10.355273762717836
# theta1的第 254 次迭代，theta1= -0.284892489001602
# theta2的第 254 次迭代，theta2= 95.53636446118863
# theta0的第 255 次迭代，theta0= -10.35528231576892
# theta1的第 255 次迭代，theta1= -0.28497064778914993
# theta2的第 255 次迭代，theta2= 95.53667476486494
# theta0的第 256 次迭代，theta0= -10.355290567708671
# theta1的第 256 次迭代，theta1= -0.2850460549858664
# theta2的第 256 次迭代，theta2= 95.5369741442578
# theta0的第 257 次迭代，theta0= -10.355298529137757
# theta1的第 257 次迭代，theta1= -0.2851188074618773
# theta2的第 257 次迭代，theta2= 95.53726298395807
# theta0的第 258 次迭代，theta0= -10.355306210283635
# theta1的第 258 次迭代，theta1= -0.2851889986769949
# theta2的第 258 次迭代，theta2= 95.53754165501711
# theta0的第 259 次迭代，theta0= -10.355313621013716
# theta1的第 259 次迭代，theta1= -0.28525671880076986
# theta2的第 259 次迭代，theta2= 95.53781051542329
# theta0的第 260 次迭代，theta0= -10.35532077084804
# theta1的第 260 次迭代，theta1= -0.2853220548282972
# theta2的第 260 次迭代，theta2= 95.53806991056206
# theta0的第 261 次迭代，theta0= -10.355327668971455
# theta1的第 261 次迭代，theta1= -0.2853850906920206
# theta2的第 261 次迭代，theta2= 95.53832017365939
# theta0的第 262 次迭代，theta0= -10.355334324245488
# theta1的第 262 次迭代，theta1= -0.285445907369529
# theta2的第 262 次迭代，theta2= 95.53856162621005
# theta0的第 263 次迭代，theta0= -10.355340745219701
# theta1的第 263 次迭代，theta1= -0.2855045829875636
# theta2的第 263 次迭代，theta2= 95.5387945783906
# theta0的第 264 次迭代，theta0= -10.355346940142628
# theta1的第 264 次迭代，theta1= -0.2855611929224088
# theta2的第 264 次迭代，theta2= 95.53901932945767
# theta0的第 265 次迭代，theta0= -10.35535291697244
# theta1的第 265 次迭代，theta1= -0.28561580989675395
# theta2的第 265 次迭代，theta2= 95.53923616813262
# theta0的第 266 次迭代，theta0= -10.355358683387143
# theta1的第 266 次迭代，theta1= -0.28566850407302286
# theta2的第 266 次迭代，theta2= 95.53944537297228
# theta0的第 267 次迭代，theta0= -10.355364246794426
# theta1的第 267 次迭代，theta1= -0.2857193431435892
# theta2的第 267 次迭代，theta2= 95.53964721272689
# theta0的第 268 次迭代，theta0= -10.35536961434119
# theta1的第 268 次迭代，theta1= -0.2857683924177119
# theta2的第 268 次迭代，theta2= 95.53984194668527
# theta0的第 269 次迭代，theta0= -10.355374792922737
# theta1的第 269 次迭代，theta1= -0.2858157149054135
# theta2的第 269 次迭代，theta2= 95.54002982500793
# theta0的第 270 次迭代，theta0= -10.355379789191614
# theta1的第 270 次迭代，theta1= -0.285861371398444
# theta2的第 270 次迭代，theta2= 95.5402110890485
# theta0的第 271 次迭代，theta0= -10.355384609566157
# theta1的第 271 次迭代，theta1= -0.285905420548372
# theta2的第 271 次迭代，theta2= 95.54038597166365
# theta0的第 272 次迭代，theta0= -10.355389260238749
# theta1的第 272 次迭代，theta1= -0.2859479189419424
# theta2的第 272 次迭代，theta2= 95.54055469751236
# theta0的第 273 次迭代，theta0= -10.35539374718378
# theta1的第 273 次迭代，theta1= -0.28598892117375174
# theta2的第 273 次迭代，theta2= 95.54071748334447
# theta0的第 274 次迭代，theta0= -10.355398076165296
# theta1的第 274 次迭代，theta1= -0.28602847991636016
# theta2的第 274 次迭代，theta2= 95.54087453827901
# theta0的第 275 次迭代，theta0= -10.355402252744422
# theta1的第 275 次迭代，theta1= -0.28606664598800985
# theta2的第 275 次迭代，theta2= 95.54102606407305
# theta0的第 276 次迭代，theta0= -10.355406282286506
# theta1的第 276 次迭代，theta1= -0.28610346841787176
# theta2的第 276 次迭代，theta2= 95.54117225538073
# theta0的第 277 次迭代，theta0= -10.355410169968014
# theta1的第 277 次迭代，theta1= -0.286138994509052
# theta2的第 277 次迭代，theta2= 95.54131330000341
# theta0的第 278 次迭代，theta0= -10.355413920783159
# theta1的第 278 次迭代，theta1= -0.28617326989931646
# theta2的第 278 次迭代，theta2= 95.54144937913081
# theta0的第 279 次迭代，theta0= -10.35541753955034
# theta1的第 279 次迭代，theta1= -0.28620633861977435
# theta2的第 279 次迭代，theta2= 95.54158066757385
# theta0的第 280 次迭代，theta0= -10.355421030918329
# theta1的第 280 次迭代，theta1= -0.2862382431513828
# theta2的第 280 次迭代，theta2= 95.54170733398927
# theta0的第 281 次迭代，theta0= -10.355424399372229
# theta1的第 281 次迭代，theta1= -0.2862690244795867
# theta2的第 281 次迭代，theta2= 95.54182954109615
# theta0的第 282 次迭代，theta0= -10.355427649239246
# theta1的第 282 次迭代，theta1= -0.2862987221469081
# theta2的第 282 次迭代，theta2= 95.54194744588509
# theta0的第 283 次迭代，theta0= -10.35543078469425
# theta1的第 283 次迭代，theta1= -0.28632737430378674
# theta2的第 283 次迭代，theta2= 95.54206119981977
# theta0的第 284 次迭代，theta0= -10.35543380976513
# theta1的第 284 次迭代，theta1= -0.28635501775755556
# theta2的第 284 次迭代，theta2= 95.54217094903159
# theta0的第 285 次迭代，theta0= -10.355436728337978
# theta1的第 285 次迭代，theta1= -0.28638168801973285
# theta2的第 285 次迭代，theta2= 95.54227683450735
# theta0的第 286 次迭代，theta0= -10.355439544162063
# theta1的第 286 次迭代，theta1= -0.28640741935168035
# theta2的第 286 次迭代，theta2= 95.54237899227041
# theta0的第 287 次迭代，theta0= -10.355442260854682
# theta1的第 287 次迭代，theta1= -0.2864322448085636
# theta2的第 287 次迭代，theta2= 95.54247755355544
# theta0的第 288 次迭代，theta0= -10.35544488190576
# theta1的第 288 次迭代，theta1= -0.2864561962818228
# theta2的第 288 次迭代，theta2= 95.54257264497691
# theta0的第 289 次迭代，theta0= -10.355447410682373
# theta1的第 289 次迭代，theta1= -0.28647930454020076
# theta2的第 289 次迭代，theta2= 95.54266438869186
# theta0的第 290 次迭代，theta0= -10.355449850433066
# theta1的第 290 次迭代，theta1= -0.28650159926916696
# theta2的第 290 次迭代，theta2= 95.54275290255674
# theta0的第 291 次迭代，theta0= -10.355452204292
# theta1的第 291 次迭代，theta1= -0.2865231091091326
# theta2的第 291 次迭代，theta2= 95.54283830027887
# theta0的第 292 次迭代，theta0= -10.355454475283004
# theta1的第 292 次迭代，theta1= -0.28654386169224666
# theta2的第 292 次迭代，theta2= 95.5429206915625
# theta0的第 293 次迭代，theta0= -10.35545666632346
# theta1的第 293 次迭代，theta1= -0.28656388367782126
# theta2的第 293 次迭代，theta2= 95.54300018224967
# theta0的第 294 次迭代，theta0= -10.35545878022804
# theta1的第 294 次迭代，theta1= -0.28658320078664595
# theta2的第 294 次迭代，theta2= 95.54307687445632
# theta0的第 295 次迭代，theta0= -10.355460819712311
# theta1的第 295 次迭代，theta1= -0.2866018378340103
# theta2的第 295 次迭代，theta2= 95.54315086670331
# theta0的第 296 次迭代，theta0= -10.355462787396263
# theta1的第 296 次迭代，theta1= -0.28661981876156983
# theta2的第 296 次迭代，theta2= 95.54322225404309
# theta0的第 297 次迭代，theta0= -10.355464685807634
# theta1的第 297 次迭代，theta1= -0.2866371666680968
# theta2的第 297 次迭代，theta2= 95.54329112818179
# theta0的第 298 次迭代，theta0= -10.355466517385171
# theta1的第 298 次迭代，theta1= -0.28665390383920597
# theta2的第 298 次迭代，theta2= 95.543357577597
# theta0的第 299 次迭代，theta0= -10.355468284481768
# theta1的第 299 次迭代，theta1= -0.28667005177590565
# theta2的第 299 次迭代，theta2= 95.54342168765143
# theta0的第 300 次迭代，theta0= -10.355469989367487
# theta1的第 300 次迭代，theta1= -0.28668563122228324
# theta2的第 300 次迭代，theta2= 95.5434835407026
# theta0的第 301 次迭代，theta0= -10.35547163423247
# theta1的第 301 次迭代，theta1= -0.2867006621921133
# theta2的第 301 次迭代，theta2= 95.54354321620863
# theta0的第 302 次迭代，theta0= -10.35547322118976
# theta1的第 302 次迭代，theta1= -0.28671516399460023
# theta2的第 302 次迭代，theta2= 95.5436007908303
# theta0的第 303 次迭代，theta0= -10.355474752277997
# theta1的第 303 次迭代，theta1= -0.2867291552591244
# theta2的第 303 次迭代，theta2= 95.54365633852952
# theta0的第 304 次迭代，theta0= -10.355476229464063
# theta1的第 304 次迭代，theta1= -0.2867426539592811
# theta2的第 304 次迭代，theta2= 95.54370993066436
# theta0的第 305 次迭代，theta0= -10.355477654645593
# theta1的第 305 次迭代，theta1= -0.2867556774358362
# theta2的第 305 次迭代，theta2= 95.54376163608075
# theta0的第 306 次迭代，theta0= -10.355479029653411
# theta1的第 306 次迭代，theta1= -0.2867682424191153
# theta2的第 306 次迭代，theta2= 95.54381152120085
# theta0的第 307 次迭代，theta0= -10.355480356253892
# theta1的第 307 次迭代，theta1= -0.2867803650504285
# theta2的第 307 次迭代，theta2= 95.54385965010846
# theta0的第 308 次迭代，theta0= -10.355481636151216
# theta1的第 308 次迭代，theta1= -0.2867920609028518
# theta2的第 308 次迭代，theta2= 95.5439060846313
# theta0的第 309 次迭代，theta0= -10.355482870989583
# theta1的第 309 次迭代，theta1= -0.28680334500119925
# theta2的第 309 次迭代，theta2= 95.5439508844204
# theta0的第 310 次迭代，theta0= -10.355484062355302
# theta1的第 310 次迭代，theta1= -0.2868142318412997
# theta2的第 310 次迭代，theta2= 95.54399410702678
# theta0的第 311 次迭代，theta0= -10.35548521177882
# theta1的第 311 次迭代，theta1= -0.28682473540870246
# theta2的第 311 次迭代，theta2= 95.54403580797536
# theta0的第 312 次迭代，theta0= -10.355486320736723
# theta1的第 312 次迭代，theta1= -0.28683486919658663
# theta2的第 312 次迭代，theta2= 95.54407604083636
# theta0的第 313 次迭代，theta0= -10.355487390653613
# theta1的第 313 次迭代，theta1= -0.2868446462230798
# theta2的第 313 次迭代，theta2= 95.54411485729396
# theta0的第 314 次迭代，theta0= -10.355488422903935
# theta1的第 314 次迭代，theta1= -0.2868540790480136
# theta2的第 314 次迭代，theta2= 95.54415230721284
# theta0的第 315 次迭代，theta0= -10.355489418813749
# theta1的第 315 次迭代，theta1= -0.28686317978904186
# theta2的第 315 次迭代，theta2= 95.54418843870221
# theta0的第 316 次迭代，theta0= -10.355490379662411
# theta1的第 316 次迭代，theta1= -0.2868719601372397
# theta2的第 316 次迭代，theta2= 95.54422329817753
# theta0的第 317 次迭代，theta0= -10.355491306684264
# theta1的第 317 次迭代，theta1= -0.28688043137207847
# theta2的第 317 次迭代，theta2= 95.54425693042023
# theta0的第 318 次迭代，theta0= -10.355492201070192
# theta1的第 318 次迭代，theta1= -0.2868886043759305
# theta2的第 318 次迭代，theta2= 95.54428937863521
# theta0的第 319 次迭代，theta0= -10.355493063969138
# theta1的第 319 次迭代，theta1= -0.2868964896480509
# theta2的第 319 次迭代，theta2= 95.54432068450635
# theta0的第 320 次迭代，theta0= -10.355493896489604
# theta1的第 320 次迭代，theta1= -0.2869040973180993
# theta2的第 320 次迭代，theta2= 95.54435088824998
# theta0的第 321 次迭代，theta0= -10.355494699701078
# theta1的第 321 次迭代，theta1= -0.2869114371590735
# theta2的第 321 次迭代，theta2= 95.54438002866668
# theta0的第 322 次迭代，theta0= -10.355495474635381
# theta1的第 322 次迭代，theta1= -0.28691851859994144
# theta2的第 322 次迭代，theta2= 95.54440814319105
# theta0的第 323 次迭代，theta0= -10.355496222288018
# theta1的第 323 次迭代，theta1= -0.2869253507377203
# theta2的第 323 次迭代，theta2= 95.54443526793973
# theta0的第 324 次迭代，theta0= -10.355496943619436
# theta1的第 324 次迭代，theta1= -0.2869319423491461
# theta2的第 324 次迭代，theta2= 95.54446143775789
# theta0的第 325 次迭代，theta0= -10.35549763955629
# theta1的第 325 次迭代，theta1= -0.286938301901991
# theta2的第 325 次迭代，theta2= 95.54448668626404
# theta0的第 326 次迭代，theta0= -10.355498310992584
# theta1的第 326 次迭代，theta1= -0.2869444375658977
# theta2的第 326 次迭代，theta2= 95.54451104589305
# theta0的第 327 次迭代，theta0= -10.355498958790871
# theta1的第 327 次迭代，theta1= -0.28695035722292733
# theta2的第 327 次迭代，theta2= 95.54453454793799
# theta0的第 328 次迭代，theta0= -10.355499583783336
# theta1的第 328 次迭代，theta1= -0.2869560684776218
# theta2的第 328 次迭代，theta2= 95.54455722259023
# theta0的第 329 次迭代，theta0= -10.355500186772856
# theta1的第 329 次迭代，theta1= -0.2869615786668018
# theta2的第 329 次迭代，theta2= 95.54457909897823
# theta0的第 330 次迭代，theta0= -10.355500768534043
# theta1的第 330 次迭代，theta1= -0.2869668948690291
# theta2的第 330 次迭代，theta2= 95.54460020520499
# theta0的第 331 次迭代，theta0= -10.35550132981425
# theta1的第 331 次迭代，theta1= -0.2869720239136108
# theta2的第 331 次迭代，theta2= 95.5446205683841
# theta0的第 332 次迭代，theta0= -10.355501871334507
# theta1的第 332 次迭代，theta1= -0.2869769723894749
# theta2的第 332 次迭代，theta2= 95.5446402146747
# theta0的第 333 次迭代，theta0= -10.355502393790477
# theta1的第 333 次迭代，theta1= -0.2869817466535737
# theta2的第 333 次迭代，theta2= 95.54465916931498
# theta0的第 334 次迭代，theta0= -10.355502897853302
# theta1的第 334 次迭代，theta1= -0.28698635283904794
# theta2的第 334 次迭代，theta2= 95.54467745665454
# theta0的第 335 次迭代，theta0= -10.35550338417053
# theta1的第 335 次迭代，theta1= -0.2869907968631459
# theta2的第 335 次迭代，theta2= 95.5446951001858
# theta0的第 336 次迭代，theta0= -10.355503853366905
# theta1的第 336 次迭代，theta1= -0.28699508443475075
# theta2的第 336 次迭代，theta2= 95.54471212257413
# theta0的第 337 次迭代，theta0= -10.355504306045145
# theta1的第 337 次迭代，theta1= -0.2869992210617988
# theta2的第 337 次迭代，theta2= 95.54472854568694
# theta0的第 338 次迭代，theta0= -10.355504742786781
# theta1的第 338 次迭代，theta1= -0.287003212058351
# theta2的第 338 次迭代，theta2= 95.54474439062182
# theta0的第 339 次迭代，theta0= -10.355505164152879
# theta1的第 339 次迭代，theta1= -0.28700706255131436
# theta2的第 339 次迭代，theta2= 95.5447596777336
# theta0的第 340 次迭代，theta0= -10.355505570684718
# theta1的第 340 次迭代，theta1= -0.2870107774871346
# theta2的第 340 次迭代，theta2= 95.54477442666048
# theta0的第 341 次迭代，theta0= -10.355505962904552
# theta1的第 341 次迭代，theta1= -0.28701436163814076
# theta2的第 341 次迭代，theta2= 95.5447886563494
# theta0的第 342 次迭代，theta0= -10.355506341316238
# theta1的第 342 次迭代，theta1= -0.2870178196086135
# theta2的第 342 次迭代，theta2= 95.54480238508015
# theta0的第 343 次迭代，theta0= -10.355506706405883
# theta1的第 343 次迭代，theta1= -0.28702115584075627
# theta2的第 343 次迭代，theta2= 95.54481563048907
# theta0的第 344 次迭代，theta0= -10.355507058642495
# theta1的第 344 次迭代，theta1= -0.2870243746204021
# theta2的第 344 次迭代，theta2= 95.54482840959156
# theta0的第 345 次迭代，theta0= -10.355507398478569
# theta1的第 345 次迭代，theta1= -0.2870274800824688
# theta2的第 345 次迭代，theta2= 95.54484073880398
# theta0的第 346 次迭代，theta0= -10.355507726350673
# theta1的第 346 次迭代，theta1= -0.28703047621631406
# theta2的第 346 次迭代，theta2= 95.54485263396481
# theta0的第 347 次迭代，theta0= -10.355508042679991
# theta1的第 347 次迭代，theta1= -0.28703336687085534
# theta2的第 347 次迭代，theta2= 95.54486411035485
# theta0的第 348 次迭代，theta0= -10.355508347872892
# theta1的第 348 次迭代，theta1= -0.28703615575950564
# theta2的第 348 次迭代，theta2= 95.544875182717
# theta0的第 349 次迭代，theta0= -10.355508642321434
# theta1的第 349 次迭代，theta1= -0.2870388464649494
# theta2的第 349 次迭代，theta2= 95.54488586527512
# theta0的第 350 次迭代，theta0= -10.355508926403875
# theta1的第 350 次迭代，theta1= -0.28704144244373114
# theta2的第 350 次迭代，theta2= 95.5448961717523
# theta0的第 351 次迭代，theta0= -10.355509200485155
# theta1的第 351 次迭代，theta1= -0.2870439470307301
# theta2的第 351 次迭代，theta2= 95.54490611538856
# theta0的第 352 次迭代，theta0= -10.355509464917366
# theta1的第 352 次迭代，theta1= -0.2870463634434032
# theta2的第 352 次迭代，theta2= 95.54491570895775
# theta0的第 353 次迭代，theta0= -10.355509720040205
# theta1的第 353 次迭代，theta1= -0.2870486947859356
# theta2的第 353 次迭代，theta2= 95.54492496478402
# theta0的第 354 次迭代，theta0= -10.355509966181412
# theta1的第 354 次迭代，theta1= -0.2870509440532389
# theta2的第 354 次迭代，theta2= 95.54493389475765
# theta0的第 355 次迭代，theta0= -10.355510203657182
# theta1的第 355 次迭代，theta1= -0.28705311413476897
# theta2的第 355 次迭代，theta2= 95.54494251035034
# theta0的第 356 次迭代，theta0= -10.35551043277258
# theta1的第 356 次迭代，theta1= -0.287055207818286
# theta2的第 356 次迭代，theta2= 95.54495082262989
# theta0的第 357 次迭代，theta0= -10.355510653821945
# theta1的第 357 次迭代，theta1= -0.28705722779339216
# theta2的第 357 次迭代，theta2= 95.5449588422745
# theta0的第 358 次迭代，theta0= -10.355510867089242
# theta1的第 358 次迭代，theta1= -0.28705917665498537
# theta2的第 358 次迭代，theta2= 95.54496657958644
# theta0的第 359 次迭代，theta0= -10.355511072848424
# theta1的第 359 次迭代，theta1= -0.2870610569066473
# theta2的第 359 次迭代，theta2= 95.54497404450527
# theta0的第 360 次迭代，theta0= -10.355511271363824
# theta1的第 360 次迭代，theta1= -0.28706287096379834
# theta2的第 360 次迭代，theta2= 95.54498124662055
# theta0的第 361 次迭代，theta0= -10.355511462890474
# theta1的第 361 次迭代，theta1= -0.287064621156808
# theta2的第 361 次迭代，theta2= 95.5449881951844
# theta0的第 362 次迭代，theta0= -10.355511647674398
# theta1的第 362 次迭代，theta1= -0.28706630973402497
# theta2的第 362 次迭代，theta2= 95.54499489912313
# theta0的第 363 次迭代，theta0= -10.355511825952972
# theta1的第 363 次迭代，theta1= -0.28706793886467186
# theta2的第 363 次迭代，theta2= 95.54500136704878
# theta0的第 364 次迭代，theta0= -10.35551199795523
# theta1的第 364 次迭代，theta1= -0.2870695106415499
# ...
# theta1的第 881 次迭代，theta1= -0.28711258510057713
# theta2的第 881 次迭代，theta2= 95.54517862019675
# theta0的第 882 次迭代，theta0= -10.355516711667663
# theta1的第 882 次迭代，theta1= -0.2871125851005865
# theta2的第 882 次迭代，theta2= 95.5451786201968
# theta0的第 883 次迭代，theta0= -10.355516711667667
# theta1的第 883 次迭代，theta1= -0.2871125851006002
# theta2的第 883 次迭代，theta2= 95.54517862019682
# theta0的第 884 次迭代，theta0= -10.35551671166767
# theta1的第 884 次迭代，theta1= -0.28711258510059673
# theta2的第 884 次迭代，theta2= 95.54517862019686
# theta0的第 885 次迭代，theta0= -10.355516711667667
# theta1的第 885 次迭代，theta1= -0.28711258510061255
# theta2的第 885 次迭代，theta2= 95.54517862019689
# theta0的第 886 次迭代，theta0= -10.35551671166767
# theta1的第 886 次迭代，theta1= -0.2871125851006215
# theta2的第 886 次迭代，theta2= 95.54517862019692
# theta0的第 887 次迭代，theta0= -10.355516711667672
# theta1的第 887 次迭代，theta1= -0.28711258510062376
# theta2的第 887 次迭代，theta2= 95.54517862019695
# theta0的第 888 次迭代，theta0= -10.355516711667672
# theta1的第 888 次迭代，theta1= -0.2871125851006292
# theta2的第 888 次迭代，theta2= 95.54517862019698
# theta0的第 889 次迭代，theta0= -10.355516711667672
# theta1的第 889 次迭代，theta1= -0.2871125851006415
# theta2的第 889 次迭代，theta2= 95.545178620197
# theta0的第 890 次迭代，theta0= -10.355516711667674
# theta1的第 890 次迭代，theta1= -0.28711258510064513
# theta2的第 890 次迭代，theta2= 95.54517862019704
# theta0的第 891 次迭代，theta0= -10.355516711667676
# theta1的第 891 次迭代，theta1= -0.28711258510065496
# theta2的第 891 次迭代，theta2= 95.54517862019706
# theta0的第 892 次迭代，theta0= -10.355516711667674
# theta1的第 892 次迭代，theta1= -0.28711258510065557
# theta2的第 892 次迭代，theta2= 95.54517862019709
# theta0的第 893 次迭代，theta0= -10.355516711667672
# theta1的第 893 次迭代，theta1= -0.28711258510067417
# theta2的第 893 次迭代，theta2= 95.54517862019712
# theta0的第 894 次迭代，theta0= -10.355516711667677
# theta1的第 894 次迭代，theta1= -0.2871125851006759
# theta2的第 894 次迭代，theta2= 95.54517862019715
# theta0的第 895 次迭代，theta0= -10.355516711667677
# theta1的第 895 次迭代，theta1= -0.2871125851006796
# theta2的第 895 次迭代，theta2= 95.54517862019718
# theta0的第 896 次迭代，theta0= -10.35551671166768
# theta1的第 896 次迭代，theta1= -0.2871125851006885
# theta2的第 896 次迭代，theta2= 95.5451786201972
# theta0的第 897 次迭代，theta0= -10.355516711667677
# theta1的第 897 次迭代，theta1= -0.2871125851006949
# theta2的第 897 次迭代，theta2= 95.54517862019723
# theta0的第 898 次迭代，theta0= -10.355516711667677
# theta1的第 898 次迭代，theta1= -0.2871125851007031
# theta2的第 898 次迭代，theta2= 95.54517862019726
# theta0的第 899 次迭代，theta0= -10.35551671166768
# theta1的第 899 次迭代，theta1= -0.28711258510071147
# theta2的第 899 次迭代，theta2= 95.54517862019729
# theta0的第 900 次迭代，theta0= -10.355516711667681
# theta1的第 900 次迭代，theta1= -0.2871125851007173
# theta2的第 900 次迭代，theta2= 95.54517862019732
# theta0的第 901 次迭代，theta0= -10.35551671166768
# theta1的第 901 次迭代，theta1= -0.28711258510072335
# theta2的第 901 次迭代，theta2= 95.54517862019735
# theta0的第 902 次迭代，theta0= -10.355516711667683
# theta1的第 902 次迭代，theta1= -0.28711258510073645
# theta2的第 902 次迭代，theta2= 95.54517862019738
# theta0的第 903 次迭代，theta0= -10.355516711667686
# theta1的第 903 次迭代，theta1= -0.2871125851007365
# theta2的第 903 次迭代，theta2= 95.5451786201974
# theta0的第 904 次迭代，theta0= -10.355516711667685
# theta1的第 904 次迭代，theta1= -0.2871125851007421
# theta2的第 904 次迭代，theta2= 95.54517862019743
# theta0的第 905 次迭代，theta0= -10.355516711667681
# theta1的第 905 次迭代，theta1= -0.2871125851007542
# theta2的第 905 次迭代，theta2= 95.54517862019746
# theta0的第 906 次迭代，theta0= -10.355516711667686
# theta1的第 906 次迭代，theta1= -0.2871125851007671
# theta2的第 906 次迭代，theta2= 95.54517862019749
# theta0的第 907 次迭代，theta0= -10.355516711667692
# theta1的第 907 次迭代，theta1= -0.28711258510076165
# theta2的第 907 次迭代，theta2= 95.54517862019752
# theta0的第 908 次迭代，theta0= -10.355516711667686
# theta1的第 908 次迭代，theta1= -0.28711258510077264
# theta2的第 908 次迭代，theta2= 95.54517862019755
# theta0的第 909 次迭代，theta0= -10.355516711667686
# theta1的第 909 次迭代，theta1= -0.2871125851007848
# theta2的第 909 次迭代，theta2= 95.54517862019758
# theta0的第 910 次迭代，theta0= -10.355516711667692
# theta1的第 910 次迭代，theta1= -0.28711258510079
# theta2的第 910 次迭代，theta2= 95.5451786201976
# theta0的第 911 次迭代，theta0= -10.35551671166769
# theta1的第 911 次迭代，theta1= -0.28711258510078963
# theta2的第 911 次迭代，theta2= 95.54517862019763
# theta0的第 912 次迭代，theta0= -10.355516711667688
# theta1的第 912 次迭代，theta1= -0.28711258510080456
# theta2的第 912 次迭代，theta2= 95.54517862019766
# theta0的第 913 次迭代，theta0= -10.355516711667692
# theta1的第 913 次迭代，theta1= -0.2871125851008112
# theta2的第 913 次迭代，theta2= 95.54517862019769
# theta0的第 914 次迭代，theta0= -10.355516711667692
# theta1的第 914 次迭代，theta1= -0.2871125851008154
# theta2的第 914 次迭代，theta2= 95.54517862019772
# theta0的第 915 次迭代，theta0= -10.355516711667692
# theta1的第 915 次迭代，theta1= -0.28711258510082516
# theta2的第 915 次迭代，theta2= 95.54517862019775
# theta0的第 916 次迭代，theta0= -10.355516711667693
# theta1的第 916 次迭代，theta1= -0.2871125851008349
# theta2的第 916 次迭代，theta2= 95.54517862019777
# theta0的第 917 次迭代，theta0= -10.355516711667693
# theta1的第 917 次迭代，theta1= -0.28711258510083726
# theta2的第 917 次迭代，theta2= 95.5451786201978
# theta0的第 918 次迭代，theta0= -10.355516711667693
# theta1的第 918 次迭代，theta1= -0.2871125851008441
# theta2的第 918 次迭代，theta2= 95.54517862019783
# theta0的第 919 次迭代，theta0= -10.355516711667695
# theta1的第 919 次迭代，theta1= -0.28711258510085413
# theta2的第 919 次迭代，theta2= 95.54517862019786
# theta0的第 920 次迭代，theta0= -10.355516711667699
# theta1的第 920 次迭代，theta1= -0.28711258510085774
# theta2的第 920 次迭代，theta2= 95.54517862019789
# theta0的第 921 次迭代，theta0= -10.355516711667697
# theta1的第 921 次迭代，theta1= -0.28711258510086574
# theta2的第 921 次迭代，theta2= 95.54517862019792
# theta0的第 922 次迭代，theta0= -10.355516711667697
# theta1的第 922 次迭代，theta1= -0.287112585100872
# theta2的第 922 次迭代，theta2= 95.54517862019794
# theta0的第 923 次迭代，theta0= -10.355516711667699
# theta1的第 923 次迭代，theta1= -0.28711258510088444
# theta2的第 923 次迭代，theta2= 95.54517862019797
# theta0的第 924 次迭代，theta0= -10.355516711667704
# theta1的第 924 次迭代，theta1= -0.28711258510088433
# theta2的第 924 次迭代，theta2= 95.545178620198
# theta0的第 925 次迭代，theta0= -10.3555167116677
# theta1的第 925 次迭代，theta1= -0.2871125851008927
# theta2的第 925 次迭代，theta2= 95.54517862019803
# theta0的第 926 次迭代，theta0= -10.3555167116677
# theta1的第 926 次迭代，theta1= -0.2871125851008994
# theta2的第 926 次迭代，theta2= 95.54517862019806
# theta0的第 927 次迭代，theta0= -10.3555167116677
# theta1的第 927 次迭代，theta1= -0.28711258510090837
# theta2的第 927 次迭代，theta2= 95.54517862019807
# theta0的第 928 次迭代，theta0= -10.355516711667706
# theta1的第 928 次迭代，theta1= -0.28711258510091237
# theta2的第 928 次迭代，theta2= 95.5451786201981
# theta0的第 929 次迭代，theta0= -10.355516711667704
# theta1的第 929 次迭代，theta1= -0.28711258510091237
# theta2的第 929 次迭代，theta2= 95.54517862019812
# theta0的第 930 次迭代，theta0= -10.3555167116677
# theta1的第 930 次迭代，theta1= -0.28711258510092014
# theta2的第 930 次迭代，theta2= 95.54517862019813
# theta0的第 931 次迭代，theta0= -10.3555167116677
# theta1的第 931 次迭代，theta1= -0.28711258510092436
# theta2的第 931 次迭代，theta2= 95.54517862019814
# theta0的第 932 次迭代，theta0= -10.355516711667704
# theta1的第 932 次迭代，theta1= -0.28711258510092985
# theta2的第 932 次迭代，theta2= 95.54517862019816
# theta0的第 933 次迭代，theta0= -10.355516711667706
# theta1的第 933 次迭代，theta1= -0.2871125851009301
# theta2的第 933 次迭代，theta2= 95.54517862019817
# theta0的第 934 次迭代，theta0= -10.355516711667702
# theta1的第 934 次迭代，theta1= -0.28711258510093196
# theta2的第 934 次迭代，theta2= 95.54517862019819
# theta0的第 935 次迭代，theta0= -10.355516711667704
# theta1的第 935 次迭代，theta1= -0.28711258510094284
# theta2的第 935 次迭代，theta2= 95.5451786201982
# theta0的第 936 次迭代，theta0= -10.355516711667706
# theta1的第 936 次迭代，theta1= -0.28711258510093685
# theta2的第 936 次迭代，theta2= 95.54517862019821
# theta0的第 937 次迭代，theta0= -10.355516711667702
# theta1的第 937 次迭代，theta1= -0.28711258510094717
# theta2的第 937 次迭代，theta2= 95.54517862019823
# theta0的第 938 次迭代，theta0= -10.355516711667708
# theta1的第 938 次迭代，theta1= -0.2871125851009517
# theta2的第 938 次迭代，theta2= 95.54517862019824
# theta0的第 939 次迭代，theta0= -10.35551671166771
# theta1的第 939 次迭代，theta1= -0.28711258510094945
# theta2的第 939 次迭代，theta2= 95.54517862019826
# theta0的第 940 次迭代，theta0= -10.355516711667708
# theta1的第 940 次迭代，theta1= -0.2871125851009555
# theta2的第 940 次迭代，theta2= 95.54517862019827
# theta0的第 941 次迭代，theta0= -10.355516711667708
# theta1的第 941 次迭代，theta1= -0.2871125851009579
# theta2的第 941 次迭代，theta2= 95.54517862019829
# theta0的第 942 次迭代，theta0= -10.355516711667706
# theta1的第 942 次迭代，theta1= -0.28711258510096277
# theta2的第 942 次迭代，theta2= 95.5451786201983
# theta0的第 943 次迭代，theta0= -10.355516711667708
# theta1的第 943 次迭代，theta1= -0.28711258510097004
# theta2的第 943 次迭代，theta2= 95.54517862019831
# theta0的第 944 次迭代，theta0= -10.35551671166771
# theta1的第 944 次迭代，theta1= -0.2871125851009656
# theta2的第 944 次迭代，theta2= 95.54517862019833
# theta0的第 945 次迭代，theta0= -10.355516711667704
# theta1的第 945 次迭代，theta1= -0.2871125851009759
# theta2的第 945 次迭代，theta2= 95.54517862019833
# theta0的第 946 次迭代，theta0= -10.355516711667711
# theta1的第 946 次迭代，theta1= -0.28711258510097626
# theta2的第 946 次迭代，theta2= 95.54517862019834
# theta0的第 947 次迭代，theta0= -10.355516711667711
# theta1的第 947 次迭代，theta1= -0.2871125851009733
# theta2的第 947 次迭代，theta2= 95.54517862019836
# theta0的第 948 次迭代，theta0= -10.35551671166771
# theta1的第 948 次迭代，theta1= -0.287112585100982
# theta2的第 948 次迭代，theta2= 95.54517862019837
# theta0的第 949 次迭代，theta0= -10.35551671166771
# theta1的第 949 次迭代，theta1= -0.287112585100985
# theta2的第 949 次迭代，theta2= 95.54517862019839
# theta0的第 950 次迭代，theta0= -10.35551671166771
# theta1的第 950 次迭代，theta1= -0.28711258510098897
# theta2的第 950 次迭代，theta2= 95.5451786201984
# theta0的第 951 次迭代，theta0= -10.35551671166771
# theta1的第 951 次迭代，theta1= -0.28711258510099263
# theta2的第 951 次迭代，theta2= 95.54517862019841
# theta0的第 952 次迭代，theta0= -10.355516711667713
# theta1的第 952 次迭代，theta1= -0.2871125851009956
# theta2的第 952 次迭代，theta2= 95.54517862019843
# theta0的第 953 次迭代，theta0= -10.355516711667711
# theta1的第 953 次迭代，theta1= -0.2871125851009956
# theta2的第 953 次迭代，theta2= 95.54517862019844
# theta0的第 954 次迭代，theta0= -10.355516711667706
# theta1的第 954 次迭代，theta1= -0.28711258510100146
# theta2的第 954 次迭代，theta2= 95.54517862019844
# theta0的第 955 次迭代，theta0= -10.35551671166771
# theta1的第 955 次迭代，theta1= -0.2871125851010086
# theta2的第 955 次迭代，theta2= 95.54517862019844
# theta0的第 956 次迭代，theta0= -10.355516711667716
# theta1的第 956 次迭代，theta1= -0.2871125851010013
# theta2的第 956 次迭代，theta2= 95.54517862019846
# theta0的第 957 次迭代，theta0= -10.355516711667711
# theta1的第 957 次迭代，theta1= -0.2871125851009997
# theta2的第 957 次迭代，theta2= 95.54517862019847
# theta0的第 958 次迭代，theta0= -10.355516711667708
# theta1的第 958 次迭代，theta1= -0.287112585101011
# theta2的第 958 次迭代，theta2= 95.54517862019847
# theta0的第 959 次迭代，theta0= -10.355516711667713
# theta1的第 959 次迭代，theta1= -0.2871125851010131
# theta2的第 959 次迭代，theta2= 95.54517862019848
# theta0的第 960 次迭代，theta0= -10.355516711667715
# theta1的第 960 次迭代，theta1= -0.2871125851010111
# theta2的第 960 次迭代，theta2= 95.5451786201985
# theta0的第 961 次迭代，theta0= -10.355516711667713
# theta1的第 961 次迭代，theta1= -0.287112585101015
# theta2的第 961 次迭代，theta2= 95.54517862019851
# theta0的第 962 次迭代，theta0= -10.355516711667713
# theta1的第 962 次迭代，theta1= -0.28711258510102305
# theta2的第 962 次迭代，theta2= 95.54517862019853
# theta0的第 963 次迭代，theta0= -10.355516711667715
# theta1的第 963 次迭代，theta1= -0.28711258510102117
# theta2的第 963 次迭代，theta2= 95.54517862019854
# theta0的第 964 次迭代，theta0= -10.355516711667711
# theta1的第 964 次迭代，theta1= -0.28711258510102483
# theta2的第 964 次迭代，theta2= 95.54517862019854
# theta0的第 965 次迭代，theta0= -10.355516711667715
# theta1的第 965 次迭代，theta1= -0.28711258510102927
# theta2的第 965 次迭代，theta2= 95.54517862019856
# theta0的第 966 次迭代，theta0= -10.355516711667713
# theta1的第 966 次迭代，theta1= -0.2871125851010277
# theta2的第 966 次迭代，theta2= 95.54517862019857
# theta0的第 967 次迭代，theta0= -10.355516711667711
# theta1的第 967 次迭代，theta1= -0.2871125851010385
# theta2的第 967 次迭代，theta2= 95.54517862019857
# theta0的第 968 次迭代，theta0= -10.355516711667718
# theta1的第 968 次迭代，theta1= -0.2871125851010322
# theta2的第 968 次迭代，theta2= 95.54517862019858
# theta0的第 969 次迭代，theta0= -10.355516711667711
# theta1的第 969 次迭代，theta1= -0.2871125851010322
# theta2的第 969 次迭代，theta2= 95.54517862019858
# theta0的第 970 次迭代，theta0= -10.355516711667711
# theta1的第 970 次迭代，theta1= -0.28711258510104287
# theta2的第 970 次迭代，theta2= 95.54517862019858
# theta0的第 971 次迭代，theta0= -10.35551671166772
# theta1的第 971 次迭代，theta1= -0.28711258510103815
# theta2的第 971 次迭代，theta2= 95.5451786201986
# theta0的第 972 次迭代，theta0= -10.355516711667716
# theta1的第 972 次迭代，theta1= -0.2871125851010347
# theta2的第 972 次迭代，theta2= 95.54517862019861
# theta0的第 973 次迭代，theta0= -10.35551671166771
# theta1的第 973 次迭代，theta1= -0.2871125851010464
# theta2的第 973 次迭代，theta2= 95.54517862019861
# theta0的第 974 次迭代，theta0= -10.355516711667715
# theta1的第 974 次迭代，theta1= -0.2871125851010512
# theta2的第 974 次迭代，theta2= 95.54517862019861
# theta0的第 975 次迭代，theta0= -10.355516711667722
# theta1的第 975 次迭代，theta1= -0.28711258510103904
# theta2的第 975 次迭代，theta2= 95.54517862019863
# theta0的第 976 次迭代，theta0= -10.355516711667711
# theta1的第 976 次迭代，theta1= -0.28711258510104465
# theta2的第 976 次迭代，theta2= 95.54517862019863
# theta0的第 977 次迭代，theta0= -10.355516711667715
# theta1的第 977 次迭代，theta1= -0.2871125851010533
# theta2的第 977 次迭代，theta2= 95.54517862019863
# theta0的第 978 次迭代，theta0= -10.35551671166772
# theta1的第 978 次迭代，theta1= -0.287112585101047
# theta2的第 978 次迭代，theta2= 95.54517862019864
# theta0的第 979 次迭代，theta0= -10.355516711667713
# theta1的第 979 次迭代，theta1= -0.28711258510104776
# theta2的第 979 次迭代，theta2= 95.54517862019864
# theta0的第 980 次迭代，theta0= -10.355516711667711
# theta1的第 980 次迭代，theta1= -0.28711258510105553
# theta2的第 980 次迭代，theta2= 95.54517862019864
# theta0的第 981 次迭代，theta0= -10.355516711667718
# theta1的第 981 次迭代，theta1= -0.2871125851010552
# theta2的第 981 次迭代，theta2= 95.54517862019866
# theta0的第 982 次迭代，theta0= -10.355516711667718
# theta1的第 982 次迭代，theta1= -0.28711258510105364
# theta2的第 982 次迭代，theta2= 95.54517862019867
# theta0的第 983 次迭代，theta0= -10.355516711667713
# theta1的第 983 次迭代，theta1= -0.2871125851010573
# theta2的第 983 次迭代，theta2= 95.54517862019867
# theta0的第 984 次迭代，theta0= -10.355516711667715
# theta1的第 984 次迭代，theta1= -0.28711258510106397
# theta2的第 984 次迭代，theta2= 95.54517862019867
# theta0的第 985 次迭代，theta0= -10.355516711667722
# theta1的第 985 次迭代，theta1= -0.2871125851010551
# theta2的第 985 次迭代，theta2= 95.54517862019868
# theta0的第 986 次迭代，theta0= -10.355516711667713
# theta1的第 986 次迭代，theta1= -0.2871125851010565
# theta2的第 986 次迭代，theta2= 95.54517862019868
# theta0的第 987 次迭代，theta0= -10.355516711667715
# theta1的第 987 次迭代，theta1= -0.2871125851010684
# theta2的第 987 次迭代，theta2= 95.54517862019868
# theta0的第 988 次迭代，theta0= -10.355516711667724
# theta1的第 988 次迭代，theta1= -0.28711258510106075
# theta2的第 988 次迭代，theta2= 95.5451786201987
# theta0的第 989 次迭代，theta0= -10.35551671166772
# theta1的第 989 次迭代，theta1= -0.28711258510106086
# theta2的第 989 次迭代，theta2= 95.54517862019871
# theta0的第 990 次迭代，theta0= -10.355516711667715
# theta1的第 990 次迭代，theta1= -0.28711258510106774
# theta2的第 990 次迭代，theta2= 95.54517862019871
# theta0的第 991 次迭代，theta0= -10.355516711667716
# theta1的第 991 次迭代，theta1= -0.28711258510107385
# theta2的第 991 次迭代，theta2= 95.54517862019871
# theta0的第 992 次迭代，theta0= -10.355516711667722
# theta1的第 992 次迭代，theta1= -0.28711258510106863
# theta2的第 992 次迭代，theta2= 95.54517862019873
# theta0的第 993 次迭代，theta0= -10.355516711667722
# theta1的第 993 次迭代，theta1= -0.2871125851010694
# theta2的第 993 次迭代，theta2= 95.54517862019874
# theta0的第 994 次迭代，theta0= -10.355516711667716
# theta1的第 994 次迭代，theta1= -0.2871125851010732
# theta2的第 994 次迭代，theta2= 95.54517862019874
# theta0的第 995 次迭代，theta0= -10.355516711667716
# theta1的第 995 次迭代，theta1= -0.2871125851010784
# theta2的第 995 次迭代，theta2= 95.54517862019874
# theta0的第 996 次迭代，theta0= -10.355516711667724
# theta1的第 996 次迭代，theta1= -0.28711258510108006
# theta2的第 996 次迭代，theta2= 95.54517862019875
# theta0的第 997 次迭代，theta0= -10.355516711667724
# theta1的第 997 次迭代，theta1= -0.2871125851010745
# theta2的第 997 次迭代，theta2= 95.54517862019877
# theta0的第 998 次迭代，theta0= -10.355516711667715
# theta1的第 998 次迭代，theta1= -0.287112585101077
# theta2的第 998 次迭代，theta2= 95.54517862019875
# theta0的第 999 次迭代，theta0= -10.355516711667716
# theta1的第 999 次迭代，theta1= -0.28711258510108567
# theta2的第 999 次迭代，theta2= 95.54517862019875
# [94.6838408648955, 84.32832415322778, 73.97280744156006, 63.90440331499343, 52.68754884802246, 42.90625730655691, 32.83785317999029, 21.908111298120403, 12.126819756654854]
